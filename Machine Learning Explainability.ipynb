# %% [markdown]
# # 1 Use Cases for Model Insights

# %% [markdown]
# ---

# %% [markdown]
# # 2 Permutation Importance
#
# ## How It Works
#
# ![image.png](attachment:dc0081b0-ab01-4806-9994-e14da7658770.png)
#
# ![image.png](attachment:7a51d43d-1fb2-4043-b739-1c98500b39c9.png)
#
#
# ## Code Example

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

data = pd.read_csv('FIFA 2018 Statistics.csv')
y = (data['Man of the Match'] == "Yes")  # Convert from string "Yes"/"No" to binary
feature_names = [i for i in data.columns if data[i].dtype in [np.int64]]
X = data[feature_names]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
my_model = RandomForestClassifier(n_estimators=100,
                                  random_state=0).fit(train_X, train_y)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

data = pd.read_csv('FIFA 2018 Statistics.csv')
y = (data['Man of the Match'] == "Yes")  # Convert from string "Yes"/"No" to binary
feature_names = [i for i in data.columns if data[i].dtype in [np.int64]]
X = data[feature_names]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
tree_model = DecisionTreeClassifier(random_state=0, max_depth=5, min_samples_split=5).fit(train_X, train_y)

# %%
from sklearn import tree
import graphviz

tree_graph = tree.export_graphviz(tree_model, out_file=None, feature_names=feature_names)
graphviz.Source(tree_graph)
# Out:
# dot: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /var/mobile/Containers/Data/Application/6DA0DD31-E331-4E9C-B26C-995A13B9EE50/Library/lib/python3.11/site-packages/graphviz/backend/execute.py:88, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      87 try:
# ---> 88     proc.check_returncode()
#      89 except subprocess.CalledProcessError as e:
#
# File /private/var/containers/Bundle/Application/12A992CB-DC3A-4820-AA6F-76A41FA7E9CE/Carnets-sci.app/Library/lib/python3.11/subprocess.py:502, in CompletedProcess.check_returncode(self)
#     501 if self.returncode:
# --> 502     raise CalledProcessError(self.returncode, self.args, self.stdout,
#     503                              self.stderr)
#
# CalledProcessError: Command '[PosixPath('dot'), '-Kdot', '-Tsvg']' returned non-zero exit status 127.
#
# ...

# %% [markdown]
# ![image.png](attachment:1c899ec6-30d9-4f82-b042-d00b4c5dea67.png)

# %%
from matplotlib import pyplot as plt
from sklearn.inspection import PartialDependenceDisplay

# Create and plot the data
disp1 = PartialDependenceDisplay.from_estimator(tree_model, val_X, ['Goal Scored'])
plt.show()

# %%
feature_to_plot = 'Distance Covered (Kms)'
disp2 = PartialDependenceDisplay.from_estimator(tree_model, val_X, [feature_to_plot])
plt.show()

# %%
# Build Random Forest model
rf_model = RandomForestClassifier(random_state=0).fit(train_X, train_y)

disp3 = PartialDependenceDisplay.from_estimator(rf_model, val_X, [feature_to_plot])
plt.show()

# %% [markdown]
# ## 2D Partial Dependence Plots

# %%
fig, ax = plt.subplots(figsize=(8, 6))
f_names = [('Goal Scored', 'Distance Covered (Kms)')]
# Similar to previous PDP plot except we use tuple of features instead of single feature
disp4 = PartialDependenceDisplay.from_estimator(tree_model, val_X, f_names, ax=ax)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 4 SHAP Values
#
# ## How They Work
#
# SHAP değerleri bağlantı kurulması gereken iki özelliği ispatlayarak hesaplar. Formülü:
#
# ```sum(SHAP values for all features) = pred_for_team - pred_for_baseline_values```
#
# ![image.png](attachment:1e09edc1-ea89-4547-a7d7-753dea0cb665.png)

# %% [markdown]
# # Code to Calculate SHAP Values

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

data = pd.read_csv('FIFA 2018 Statistics.csv')
y = (data['Man of the Match'] == "Yes")  # Convert from string "Yes"/"No" to binary
feature_names = [i for i in data.columns if data[i].dtype in [np.int64, np.int64]]
X = data[feature_names]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
my_model = RandomForestClassifier(random_state=0).fit(train_X, train_y)

# %%
row_to_show = 5
data_for_prediction = val_X.iloc[row_to_show]  # use 1 row of data here. Could use multiple rows if desired
data_for_prediction_array = data_for_prediction.values.reshape(1, -1)


my_model.predict_proba(data_for_prediction_array)
# Out:
# /private/var/containers/Bundle/Application/12A992CB-DC3A-4820-AA6F-76A41FA7E9CE/Carnets-sci.app/Library/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([[0.29, 0.71]])

# %%
# !pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached shap-0.46.0.tar.gz (1.2 MB)
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached numba-0.60.0.tar.gz (2.7 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       segmentation fault
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# ...

# %%
import shap  # package used to calculate Shap values

# Create object that can calculate shap values
explainer = shap.TreeExplainer(my_model)

# Calculate Shap values
shap_values = explainer.shap_values(data_for_prediction)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import shap  # package used to calculate Shap values
#       3 # Create object that can calculate shap values
#       4 explainer = shap.TreeExplainer(my_model)
#
# ModuleNotFoundError: No module named 'shap'

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[1], shap_values[1], data_for_prediction)

# %%
# use Kernel SHAP to explain test set predictions
k_explainer = shap.KernelExplainer(my_model.predict_proba, train_X)
k_shap_values = k_explainer.shap_values(data_for_prediction)
shap.force_plot(k_explainer.expected_value[1], k_shap_values[1], data_for_prediction)

# %% [markdown]
# ---

# %% [markdown]
# # Advanced Uses of SHAP Values
#
#
# ## SHAP Values Review
#
#
# Shap değerleri herhangi bir tahmini her bir özellik değerinin etkilerinin toplamına ayrıştırmamıza izin vererek şöyle bir grafik verir:
#
# ![image.png](attachment:2682d048-4d42-4bd0-91a7-81a068e1b70a.png)
#
# # Summary Plots
#
#
# SHAP özet grafikleri bize özellik önemine ve onu neyin yönlendirdiğine dair kuş bakışı bir bakış açısı veriyor. Futbol verileri için örnek bir arsa üzerinden geçeceğiz:
#
# ![image.png](attachment:4632c517-8d41-403d-a9d1-f79ee5ff8865.png)
#
# # Summary Plots in Code

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

data = pd.read_csv('FIFA 2018 Statistics.csv')
y = (data['Man of the Match'] == "Yes")  # Convert from string "Yes"/"No" to binary
feature_names = [i for i in data.columns if data[i].dtype in [np.int64, np.int64]]
X = data[feature_names]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
my_model = RandomForestClassifier(random_state=0).fit(train_X, train_y)

# %%
import shap  # package used to calculate Shap values

# Create object that can calculate shap values
explainer = shap.TreeExplainer(my_model)

# calculate shap values. This is what we will plot.
# Calculate shap_values for all of val_X rather than a single row, to have more data for plot.
shap_values = explainer.shap_values(val_X)

# Make plot. Index of [1] is explained in text below.
shap.summary_plot(shap_values[1], val_X)

# %% [markdown]
# # SHAP Dependence Contribution Plots
#
# ![image.png](attachment:9a1f13b8-accd-454b-8c78-0df2445b95ef.png)
#
# ![image.png](attachment:fc42a6d9-4d69-47ed-bced-c901d615cd9a.png)
#
# ![image.png](attachment:d33b8908-f706-4ded-af29-174d473ca8dc.png)
#
# Bu iki nokta, yukarı yönlü eğilimden uzak olduğu için uzamsal olarak öne çıkıyor. Her ikisi de mor renklidir, bu da takımın bir gol attığını gösterir. Bunu **Genel olarak, topa sahip olmak bir takımın oyuncusunun ödülü kazanma şansını artırır. Ancak sadece bir gol atarlarsa, bu eğilim tersine döner ve ödül jürileri o kadar az gol atarlarsa topa bu kadar çok sahip oldukları için onları cezalandırabilir.**
#
# # Dependence Contribution Plots in Code

# %%
import shap  # package used to calculate Shap values

# Create object that can calculate shap values
explainer = shap.TreeExplainer(my_model)

# calculate shap values. This is what we will plot.
shap_values = explainer.shap_values(X)

# make plot.
shap.dependence_plot('Ball Possession %', shap_values[1], X, interaction_index="Goal Scored")

# %% [markdown]
# ---
